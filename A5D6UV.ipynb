# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;

plt.rcParams["figure.figsize"] = [10.00, 10.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.plot(firstfiledata[:, 1], firstfiledata[:, 2], label="Dark ");
plt.plot(afiledata[:, 1], afiledata[:, 2], label="0,12 μW ");
plt.plot(bfiledata[:, 1], bfiledata[:, 2], label="0,44 μW ");
plt.plot(cfiledata[:, 1], cfiledata[:, 2], label="1,47 μW ");
plt.plot(secondfiledata[:, 1], secondfiledata[:, 2], label="3,13 μW ");
plt.plot(thirdfiledata[:, 1], thirdfiledata[:, 2], label="5,02 μW ");
plt.plot(forthfiledata[:, 1], forthfiledata[:, 2], label="7,88 μW ");
plt.plot(fifthfiledata[:, 1], fifthfiledata[:, 2], label="12,8 μW ");
plt.legend();
plt.title("Au/MWCNTs CVD/Si3N4/n-Si/Au under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('Current(A)',fontweight ="bold",size=20)
plt.show();

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;
from scipy.signal import savgol_filter

plt.rcParams["figure.figsize"] = [15.00, 5.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.plot(firstfiledata[:, 1],(afiledata[:, 2]-firstfiledata[:, 2])*37575757*100, label="E.Q.E for 0,12 μW ");
plt.plot(firstfiledata[:, 1],(bfiledata[:, 2]-firstfiledata[:, 2])*10247933*100, label="E.Q.E for 0,44 μW ");
plt.plot(firstfiledata[:, 1],(cfiledata[:, 2]-firstfiledata[:, 2])*3067408*100, label="E.Q.E for 1,47 μW ");
plt.plot(firstfiledata[:, 1],(secondfiledata[:, 2]-firstfiledata[:, 2])*1440604*100, label="E.Q.E for 3,13 μW ");
plt.plot(secondfiledata[:, 1],(thirdfiledata[:, 2]-firstfiledata[:, 2])*898225.3*100, label="E.Q.E for 5,02 μW ");
plt.plot(thirdfiledata[:, 1], (forthfiledata[:, 2]-firstfiledata[:, 2])*572219.7*100, label="E.Q.E for 7,88 μW ");
plt.plot(forthfiledata[:, 1], (fifthfiledata[:, 2]-firstfiledata[:, 2])*352272.7*100, label="E.Q.E for 12,8 μW ");

plt.legend();
plt.title("Au/MWCNTs CVD/Si3N4/n-Si/Au E.Q.E under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('E.Q.E (%)',fontweight ="bold",size=20)
plt.ylim(0,200)
plt.show();
#save data
import numpy as np
V1=(secondfiledata[:, 2]-firstfiledata[:, 2])*1440604*100
V2=(thirdfiledata[:, 2]-firstfiledata[:, 2])*898225.3*100
V3=(forthfiledata[:, 2]-firstfiledata[:, 2])*572219.7*100
V4=(fifthfiledata[:, 2]-firstfiledata[:, 2])*352272.7*100

data = np.array([firstfiledata[:, 1],V1]) #mesh_x and mesh_y - nodes that used in triangulation
data = np.transpose(data)
np.savetxt('CVD140 UV 3,13μW.txt', data, delimiter = ' ')
data = np.array([firstfiledata[:, 1],V2]) #mesh_x and mesh_y - nodes that used in triangulation
data = np.transpose(data)
np.savetxt('CVD140 UV 5,02 μW.txt', data, delimiter = ' ')
data = np.array([firstfiledata[:, 1],V3]) #mesh_x and mesh_y - nodes that used in triangulation
data = np.transpose(data)
np.savetxt('CVD140 UV 7,88μW.txt', data, delimiter = ' ')
data = np.array([firstfiledata[:, 1],V4]) #mesh_x and mesh_y - nodes that used in triangulation
data = np.transpose(data)
np.savetxt('CVD140 UV 12,8μW.txt', data, delimiter = ' ')

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;

plt.rcParams["figure.figsize"] = [15.00, 5.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.plot(firstfiledata[:, 1],(afiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 0,12μW");
plt.plot(firstfiledata[:, 1],(bfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 0,44μW");
plt.plot(firstfiledata[:, 1],(cfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 1,47");
plt.plot(firstfiledata[:, 1],(secondfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 3,13 μW ");
plt.plot(secondfiledata[:, 1],(thirdfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 5,02 μW ");
plt.plot(thirdfiledata[:, 1], (forthfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 7,88 μW ");
plt.plot(forthfiledata[:, 1], (fifthfiledata[:, 2]-firstfiledata[:, 2])/(firstfiledata[:, 2]), label="Iph/Id for 12,8 μW ");

plt.legend();
plt.title("Au/MWCNTsCVD/Si3N4/n-Si/Au Photocurrent under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('Iph/Id',fontweight ="bold",size=20)
plt.xlim(1,8)
plt.ylim(0,4)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.1)
plt.savefig("foo.jpeg", bbox_inches='tight')#cfiledata[:,2]
plt.show()

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;

plt.rcParams["figure.figsize"] = [10.00, 5.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.plot(firstfiledata[:, 1],(afiledata[:, 2]-firstfiledata[:, 2])/(0.12*10**(-6)), label="Responsivity for 0,12 μW ");
plt.plot(firstfiledata[:, 1],(bfiledata[:, 2]-firstfiledata[:, 2])/(0.44*10**(-6)), label="Responsivity for 0,44 μW ");
plt.plot(firstfiledata[:, 1],(cfiledata[:, 2]-firstfiledata[:, 2])/(1.47*10**(-6)), label="Responsivity for 1,47 μW ");
plt.plot(firstfiledata[:, 1],(secondfiledata[:, 2]-firstfiledata[:, 2])/(3.13*10**(-6)), label="Responsivity for 3,13 μW ");
plt.plot(secondfiledata[:, 1],(thirdfiledata[:, 2]-firstfiledata[:, 2])/(5.02*10**(-6)), label="Responsivity for 5,02 μW ");
plt.plot(thirdfiledata[:, 1], (forthfiledata[:, 2]-firstfiledata[:, 2])/(7.88*10**(-6)), label="Responsivity for 7,88 μW ");
plt.plot(forthfiledata[:, 1], (fifthfiledata[:, 2]-firstfiledata[:, 2])/(12.8*10**(-6)), label="Responsivity for 12,8 μW ");

plt.legend();
plt.title("Au/MWCNTs CVD/Si3N4/n-Si/Au Responsivity under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('Responsivity (A/W)',fontweight ="bold",size=20)
plt.ylim(0,0.09)
plt.show();

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;
from scipy.interpolate import interp1d
import numpy as np
plt.rcParams["figure.figsize"] = [10.00, 5.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
a=firstfiledata[:,1]
b=(afiledata[:, 2]-firstfiledata[:, 2])/(0.12*10**(-6))
cubic_interploation_model = interp1d(a, b, kind = "cubic")
X_=np.linspace(a.min(), a.max(), 10)
Y_=cubic_interploation_model(X_)
c=firstfiledata[:,1]
d=(bfiledata[:, 2]-firstfiledata[:, 2])/(0.44*10**(-6))
cubic_interploation_model = interp1d(c, d, kind = "cubic")
X_1=np.linspace(a.min(), a.max(), 10)
Y_1=cubic_interploation_model(X_)
plt.style.use('fivethirtyeight')
plt.plot(X_, Y_,label="Responsivity for 0,12 μW ")
plt.plot(X_1, Y_1,label="Responsivity for 0,44 μW ")
plt.legend();
plt.title("Plot Smooth Curve Using the scipy.interpolate.interp1d Class Au/MWCNTs CVD/Si3N4/n-Si/Au Responsivity under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('Responsivity (A/W)',fontweight ="bold",size=20)
plt.ylim(0,0.7)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.1)

plt.show()

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;

plt.rcParams["figure.figsize"] = [15.00, 5.0]
plt.rcParams["figure.autolayout"] = True

firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
bfiledata = genfromtxt("D650.txt",skip_header=4);
cfiledata = genfromtxt("D652.txt",skip_header=4);
secondfiledata = genfromtxt("D654.txt",skip_header=4);
thirdfiledata = genfromtxt("D656.txt",skip_header=4);
forthfiledata = genfromtxt("D658.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.plot(firstfiledata[:, 1],(afiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 0,12μW");
plt.plot(firstfiledata[:, 1],(bfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 0,44μW");
plt.plot(firstfiledata[:, 1],(cfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 1,47");
plt.plot(firstfiledata[:, 1],(secondfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 3,13 μW ");
plt.plot(secondfiledata[:, 1],(thirdfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 5,02 μW ");
plt.plot(thirdfiledata[:, 1], (forthfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 7,88 μW ");
plt.plot(forthfiledata[:, 1], (fifthfiledata[:, 2]-firstfiledata[:, 2]), label="Iph for 12,8 μW ");

plt.legend();
plt.title("Au/MWCNTsCVD/Si3N4/n-Si/Au Photocurrent under UV illumination")
plt.xlabel('Bias(V)',fontweight ="bold",size=20)
plt.ylabel('Iph/Id',fontweight ="bold",size=20)
plt.xlim(1,8)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.1)

plt.show()

# %%
from matplotlib import pyplot as plt;
from pylab import genfromtxt;
from scipy.signal import savgol_filter
import numpy as np
plt.rcParams["figure.figsize"] = [10.00, 5.0]
plt.rcParams["figure.autolayout"] = True
firstfiledata = genfromtxt("D6D.txt",skip_header=4);
afiledata = genfromtxt("D648.txt",skip_header=4);
fifthfiledata = genfromtxt("D660.txt",skip_header=4);
plt.style.use('fivethirtyeight')
x=firstfiledata[:, 1]
y=(afiledata[:, 2]-firstfiledata[:, 2])
x1=firstfiledata[:, 1]
y1=(fifthfiledata[:, 2]-firstfiledata[:, 2])
x2=firstfiledata[:, 1]
plt.ylabel('Photocurrent (A)',fontweight ="bold",size=20)
model = np.polyfit(x,y,3) # fitting - 1 is the exp 
predict = np.poly1d(model)
print(predict)
x_lin_reg =np.linspace(0,8) #This sets the range you want to display the linear regression model over
y_lin_reg = predict(x_lin_reg)#This calculates the y values for all the x values
plt.plot(x_lin_reg, y_lin_reg,'-', c = 'r',label="E.Q.E for 0,12 μW ")
model = np.polyfit(x1,y1,3) # fitting - 1 is the exp 
predict = np.poly1d(model)
print(predict)
x_lin_reg =np.linspace(0,8) #This sets the range you want to display the linear regression model over
y_lin_reg = predict(x_lin_reg)#This calculates the y values for all the x values
plt.plot(x_lin_reg, y_lin_reg,'-', c = 'b',label="E.Q.E for 12,8 μW ")
plt.xlim(3,8)
plt.legend();
plt.title("Au/MWCNTs CVD/Si3N4(140nm)/n-Si/Au Photocurrent under UV illumination",size=10)
plt.savefig("140nm photocurrent 0,12μW and 12μW  fivethirtyeight.jpeg", bbox_inches='tight')#cfiledata[:,2]
#the plot answering why the qe decresing as the power increase the photocurrents at those two powers are very close thats phy the optical power becomes important
# Out:
#             3             2
# -9.112e-10 x + 1.031e-08 x - 2.257e-08 x + 9.067e-09
#             3            2
# -7.103e-09 x + 7.79e-08 x - 1.537e-07 x + 5.101e-08
